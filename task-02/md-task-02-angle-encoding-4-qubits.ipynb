# %% [markdown]
# # Angle Encoding - 4 qubits - using qml.AngleEmbedding

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from ipywidgets import widgets
from IPython.display import display, HTML

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.optimize import NesterovMomentumOptimizer

import sys
from math import sqrt, pi
import time

import pandas as pd
import scipy
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
# supress a warning that is not useful here
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Data Loading and Exploration
#
# Second and third columns looks better as decimal logarithms. Also it seems they are highly corelated and eventually can be compressed to one feature.

# %%
## #################################################################################
# globals

path_train = '/_jupyter/QC/QOSF-challenge-md-2022/task-02/mock_train_set.csv'
path_test = '/_jupyter/QC/QOSF-challenge-md-2022/task-02/mock_test_set.csv'

num_qubits = 4
num_layers = 6

dev = qml.device("default.qubit", wires=num_qubits)

## #################################################################################
df = pd.read_csv(path_train)
df_c = df.copy(deep=True)
df['1'] = np.log10(df_c['1'])
df['2'] = np.log10(df_c['2'])

f = lambda x: -1.0 if x==0 else 1.0
df['4'] = df_c['4'].map(f)

npdf = df.to_numpy()
data = np.array(npdf)

print("Train data standardised:\n", data)

X = data[:, 0:4]
Y = data[:, -1]

# scale the data using sklearn StandardScaler
# std_slc = StandardScaler(with_mean=False)
std_slc = StandardScaler(with_mean=True)
std_slc.fit(X)
X_std = std_slc.transform(X)

# normalize data using sklearn StandardScaler
normalizer = Normalizer().fit(X_std)  # fit does nothing.
X_norm = normalizer.transform(X_std)

# features will be the angles vector
# features = np.array(X_norm, requires_grad=False)
features = np.array(X_std, requires_grad=False)
# features = np.array(X, requires_grad=False)
print("Train data normalized:\n", features)
# Out:
# Train data standardised:
#  [[ 2.78926e+03  3.00000e+00  1.00000e+00  2.00000e+01 -1.00000e+00]
#  [ 4.04001e+03  6.00000e+00  0.00000e+00  1.00000e+00  1.00000e+00]
#  [ 2.93120e+03  4.00000e+00  4.00000e+00  4.00000e+01  1.00000e+00]
#  ...
#  [ 4.18281e+03  0.00000e+00  0.00000e+00  6.50000e+01 -1.00000e+00]
#  [ 3.11375e+03  4.00000e+00  2.00000e+00  1.00000e+00  1.00000e+00]
#  [ 4.56757e+03  4.00000e+00  5.00000e+00  9.00000e+01  1.00000e+00]]
# StandardScaler()
# Train data normalized:
#  [[ 0.11203099 -0.04899659 -0.85833249 -0.95544758]
#  [ 0.99674452  1.21091584 -1.35930477 -1.64780089]
#  [ 0.21243174  0.37097422  0.64458432 -0.22665461]
#  ...
#  [ 1.09775359 -1.30890903 -1.35930477  0.68433659]
#  [ 0.34155783  0.37097422 -0.35736022 -1.64780089]
#  [ 1.3699122   0.37097422  1.1455566   1.5953278 ]]

# %% [markdown]
# ## Data Encoding, Circuit Preparation and Cost Functions

# %%
# ###################################################################
# layer circuit - this is where the circuit learns
def layer(W):

    qml.Rot(W[0, 0], W[0, 1], W[0, 2], wires=0)
    qml.Rot(W[1, 0], W[1, 1], W[1, 2], wires=1)
    qml.Rot(W[2, 0], W[2, 1], W[2, 2], wires=2)
    qml.Rot(W[3, 0], W[3, 1], W[3, 2], wires=3)

    qml.CNOT(wires=[0, 1])
    qml.CNOT(wires=[1, 2])
    qml.CNOT(wires=[2, 3])
    qml.CNOT(wires=[3, 0])

# ###################################################################
# the circuit - where the action happens
@qml.qnode(dev)
def circuit(weights, data):

    qml.AngleEmbedding(features=data, wires=range(num_qubits), rotation='Y')

    for W in weights:
        layer(W)

    # return qml.expval(qml.PauliZ(0))
    return qml.expval(qml.PauliY(0))

draw_flag = 0

# ###############################################################################
# variational classifier
# this will be called on each optimization step by the cost evaluation
def variational_classifier(weights, bias, data):
    
    global draw_flag

    if draw_flag:
        draw_flag=0
        # qml.draw

    return circuit(weights, data) + bias

# ###############################################################################
# standard square loss
def square_loss(labels, predictions):
    
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

# ###############################################################################
# goal: maximize accuracy
def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

# ###############################################################################
# cost function - will be called during optimization process
def cost(weights, bias, features, labels):
    
    predictions = [variational_classifier(weights, bias, f) for f in features]
    return square_loss(labels, predictions)

# %% [markdown]
# ## Datasets Preparation

# %%
np.random.seed(0)
num_data = len(Y)

num_train = int(0.75 * num_data)
index = np.random.permutation(range(num_data))

feats_train = features[index[:num_train]]
Y_train = Y[index[:num_train]]

feats_val = features[index[num_train:]]
Y_val = Y[index[num_train:]]

# We need these later for plotting
X_train = X[index[:num_train]]
X_val = X[index[num_train:]]

# ######################################################################
# Load the test dataset and apply same transformations as we did with the train dataset.
df_test = pd.read_csv(path_test)
df_test_c = df_test.copy(deep=True)
df_test['1'] = np.log10(df_test_c['1'])
df_test['2'] = np.log10(df_test_c['2'])

f = lambda x: -1.0 if x==0 else 1.0
df_test['4'] = df_test_c['4'].map(f)
data_test = df_test.to_numpy()

X_test_ini = data_test[:, 0:4]
Y_test = data_test[:, -1]

# scale data using sklearn StandardScaler
std_slc = StandardScaler(with_mean=False)
std_slc.fit(X_test_ini)
X_test_std = std_slc.transform(X_test_ini)

# normalize data using sklearn Normalizer
normalizer = Normalizer().fit(X_test_std)  # fit does nothing.
X_test_norm = normalizer.transform(X_test_std)

# convert to a pennylane numpy array
X_test = np.array(X_test_norm, requires_grad=False)


# ######################################################################
# accuracy for test dtaset
def test_accuracy(weights, bias):
    # apply the variational clasifier circuit on test dataset
    # using the learned weights
    predictions_test = [np.sign(variational_classifier(weights, bias, f)) for f in X_test]

    return accuracy(Y_test, predictions_test)
# Out:
# StandardScaler(with_mean=False)

# %% [markdown]
# ## Training

# %%
weights_init = 0.01 * np.random.randn(num_layers, num_qubits, 3, requires_grad=True)
bias_init = np.array(0.0, requires_grad=True)

# # start with learned weights
# w = np.load('/_jupyter/QC/QOSF-challenge-md-2022/task-02/temp-data/variational_classifier/data/mock_train_numpy_wights_01.npy', allow_pickle=True)
# weights_init = np.array(w, requires_grad=True)
# bias_init = np.array(-0.483902119474, requires_grad=True)


opt = NesterovMomentumOptimizer(0.01)

# batch_size = 5
# batch_size = 15
# batch_size = 20
batch_size = 10


# train the variational classifier
weights = weights_init
bias = bias_init
steps = 60

toc = time.time()
for it in range(steps):

    # Update the weights by one optimizer step
    batch_index = np.random.randint(0, num_train, (batch_size,))
    feats_train_batch = feats_train[batch_index]
    Y_train_batch = Y_train[batch_index]
    weights, bias, _, _ = opt.step(cost, weights, bias, feats_train_batch, Y_train_batch)

    # Compute predictions on train and validation set
    predictions_train = [np.sign(variational_classifier(weights, bias, f)) for f in feats_train]
    predictions_val = [np.sign(variational_classifier(weights, bias, f)) for f in feats_val]

    # Compute accuracy on train and validation set
    acc_train = accuracy(Y_train, predictions_train)
    acc_val = accuracy(Y_val, predictions_val)
    acc_test = test_accuracy(weights, bias)

    print(
        "Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} | Acc test: {:0.7f} "
        "".format(it + 1, cost(weights, bias, features, Y), acc_train, acc_val, acc_test)
    )

    if acc_train >= 0.93 and acc_val >= 0.93:
        # early stop
        break

tic = time.time()

print('\n\ntime in sec. for {} steps: {}'.format(it+1, tic-toc))
print('\nbias: ', bias)    
print('\nweights:\n', weights)
# Out:
# Iter:     1 | Cost: 0.9996915 | Acc train: 0.5155556 | Acc validation: 0.4133333 | Acc test: 0.5166667
# Iter:     2 | Cost: 0.9997428 | Acc train: 0.5777778 | Acc validation: 0.5066667 | Acc test: 0.8166667
# Iter:     3 | Cost: 1.0003390 | Acc train: 0.5066667 | Acc validation: 0.4666667 | Acc test: 0.7750000
# Iter:     4 | Cost: 1.0002712 | Acc train: 0.4888889 | Acc validation: 0.4800000 | Acc test: 0.6333333
# Iter:     5 | Cost: 0.9972879 | Acc train: 0.5111111 | Acc validation: 0.5600000 | Acc test: 0.4833333
# Iter:     6 | Cost: 0.9953458 | Acc train: 0.5200000 | Acc validation: 0.5733333 | Acc test: 0.4833333
# Iter:     7 | Cost: 0.9953687 | Acc train: 0.5288889 | Acc validation: 0.5200000 | Acc test: 0.4833333
# Iter:     8 | Cost: 0.9953362 | Acc train: 0.5244444 | Acc validation: 0.5200000 | Acc test: 0.4833333
# Iter:     9 | Cost: 0.9956799 | Acc train: 0.5066667 | Acc validation: 0.5200000 | Acc test: 0.4833333
# Iter:    10 | Cost: 0.9955640 | Acc train: 0.5066667 | Acc validation: 0.5333333 | Acc test: 0.4833333
# Iter:    11 | Cost: 0.9957356 | Acc train: 0.5111111 | Acc validation: 0.5333333 | Acc test: 0.4833333
# Iter:    12 | Cost: 0.9952047 | Acc train: 0.5155556 | Acc validation: 0.5466667 | Acc test: 0.4833333
# Iter:    13 | Cost: 0.9955467 | Acc train: 0.4977778 | Acc validation: 0.5466667 | Acc test: 0.4833333
# Iter:    14 | Cost: 0.9968001 | Acc train: 0.5066667 | Acc validation: 0.5466667 | Acc test: 0.4833333
# Iter:    15 | Cost: 0.9961914 | Acc train: 0.5022222 | Acc validation: 0.5466667 | Acc test: 0.4833333
# Iter:    16 | Cost: 0.9943315 | Acc train: 0.4933333 | Acc validation: 0.5733333 | Acc test: 0.4833333
# Iter:    17 | Cost: 0.9937168 | Acc train: 0.4977778 | Acc validation: 0.5866667 | Acc test: 0.4833333
# Iter:    18 | Cost: 0.9904994 | Acc train: 0.5022222 | Acc validation: 0.5866667 | Acc test: 0.4833333
# Iter:    19 | Cost: 0.9860003 | Acc train: 0.5066667 | Acc validation: 0.6133333 | Acc test: 0.4833333
# Iter:    20 | Cost: 0.9830670 | Acc train: 0.5155556 | Acc validation: 0.6133333 | Acc test: 0.4916667
# Iter:    21 | Cost: 0.9800771 | Acc train: 0.5422222 | Acc validation: 0.6000000 | Acc test: 0.5416667
# Iter:    22 | Cost: 0.9769889 | Acc train: 0.5777778 | Acc validation: 0.5866667 | Acc test: 0.2750000
# Iter:    23 | Cost: 0.9722852 | Acc train: 0.5866667 | Acc validation: 0.6000000 | Acc test: 0.2833333
# Iter:    24 | Cost: 0.9679100 | Acc train: 0.5911111 | Acc validation: 0.6133333 | Acc test: 0.2916667
# Iter:    25 | Cost: 0.9645451 | Acc train: 0.6000000 | Acc validation: 0.5866667 | Acc test: 0.2750000
# Iter:    26 | Cost: 0.9625196 | Acc train: 0.5733333 | Acc validation: 0.6000000 | Acc test: 0.3500000
# Iter:    27 | Cost: 0.9564874 | Acc train: 0.5955556 | Acc validation: 0.6000000 | Acc test: 0.3500000
# Iter:    28 | Cost: 0.9514553 | Acc train: 0.6000000 | Acc validation: 0.6266667 | Acc test: 0.3583333
# Iter:    29 | Cost: 0.9437093 | Acc train: 0.6177778 | Acc validation: 0.6666667 | Acc test: 0.3833333
# Iter:    30 | Cost: 0.9346276 | Acc train: 0.6577778 | Acc validation: 0.7066667 | Acc test: 0.3833333
# Iter:    31 | Cost: 0.9217149 | Acc train: 0.7022222 | Acc validation: 0.7066667 | Acc test: 0.5083333
# Iter:    32 | Cost: 0.9081402 | Acc train: 0.7333333 | Acc validation: 0.6800000 | Acc test: 0.7000000
# Iter:    33 | Cost: 0.8948753 | Acc train: 0.7377778 | Acc validation: 0.6533333 | Acc test: 0.7250000
# Iter:    34 | Cost: 0.8818136 | Acc train: 0.7555556 | Acc validation: 0.7066667 | Acc test: 0.7500000
# Iter:    35 | Cost: 0.8682854 | Acc train: 0.7377778 | Acc validation: 0.7066667 | Acc test: 0.7500000
# Iter:    36 | Cost: 0.8578934 | Acc train: 0.7644444 | Acc validation: 0.7066667 | Acc test: 0.7833333
# Iter:    37 | Cost: 0.8462526 | Acc train: 0.7555556 | Acc validation: 0.7333333 | Acc test: 0.8083333
# Iter:    38 | Cost: 0.8329627 | Acc train: 0.7733333 | Acc validation: 0.7333333 | Acc test: 0.8250000
# Iter:    39 | Cost: 0.8204939 | Acc train: 0.7777778 | Acc validation: 0.7466667 | Acc test: 0.8250000
# Iter:    40 | Cost: 0.8051427 | Acc train: 0.7733333 | Acc validation: 0.7466667 | Acc test: 0.8333333
# Iter:    41 | Cost: 0.7878242 | Acc train: 0.7911111 | Acc validation: 0.7733333 | Acc test: 0.8583333
# Iter:    42 | Cost: 0.7693254 | Acc train: 0.8133333 | Acc validation: 0.8133333 | Acc test: 0.8750000
# Iter:    43 | Cost: 0.7528446 | Acc train: 0.8400000 | Acc validation: 0.8533333 | Acc test: 0.9166667
# Iter:    44 | Cost: 0.7364632 | Acc train: 0.8622222 | Acc validation: 0.8800000 | Acc test: 0.9000000
# Iter:    45 | Cost: 0.7210832 | Acc train: 0.8711111 | Acc validation: 0.8666667 | Acc test: 0.8333333
# Iter:    46 | Cost: 0.7062485 | Acc train: 0.8711111 | Acc validation: 0.8800000 | Acc test: 0.7666667
# Iter:    47 | Cost: 0.6909844 | Acc train: 0.8711111 | Acc validation: 0.8933333 | Acc test: 0.7833333
# Iter:    48 | Cost: 0.6756692 | Acc train: 0.8711111 | Acc validation: 0.9066667 | Acc test: 0.8666667
# Iter:    49 | Cost: 0.6600981 | Acc train: 0.8800000 | Acc validation: 0.9066667 | Acc test: 0.8583333
# Iter:    50 | Cost: 0.6454642 | Acc train: 0.8800000 | Acc validation: 0.9066667 | Acc test: 0.8583333
# Iter:    51 | Cost: 0.6294416 | Acc train: 0.8800000 | Acc validation: 0.9066667 | Acc test: 0.8666667
# Iter:    52 | Cost: 0.6159879 | Acc train: 0.8755556 | Acc validation: 0.9066667 | Acc test: 0.8750000
# Iter:    53 | Cost: 0.6011057 | Acc train: 0.8755556 | Acc validation: 0.9200000 | Acc test: 0.8750000
# Iter:    54 | Cost: 0.5863287 | Acc train: 0.8711111 | Acc validation: 0.9333333 | Acc test: 0.8916667
# Iter:    55 | Cost: 0.5723144 | Acc train: 0.8800000 | Acc validation: 0.9200000 | Acc test: 0.8833333
# Iter:    56 | Cost: 0.5603192 | Acc train: 0.8844444 | Acc validation: 0.9333333 | Acc test: 0.8583333
# Iter:    57 | Cost: 0.5481262 | Acc train: 0.8933333 | Acc validation: 0.9333333 | Acc test: 0.8250000
# Iter:    58 | Cost: 0.5363093 | Acc train: 0.8933333 | Acc validation: 0.9200000 | Acc test: 0.7833333
# Iter:    59 | Cost: 0.5257778 | Acc train: 0.8888889 | Acc validation: 0.9066667 | Acc test: 0.7166667
# Iter:    60 | Cost: 0.5165384 | Acc train: 0.8888889 | Acc validation: 0.9066667 | Acc test: 0.6416667
#
#
# time in sec. for 60 steps: 510.4022419452667
#
# bias:  -0.03231640681419419
#
# weights:
#  [[[ 1.62650748e-02  6.62966616e-02 -6.48880526e-03]
#   [-5.03126747e-03  6.60351904e-02  1.85466137e-02]
#   [ 3.55746771e-02  2.83041734e-02  1.38672893e-02]
#   [ 8.77028019e-03 -3.36752008e-01 -1.80516101e-02]]
#
#  [[-3.18101983e-01 -2.86223415e-02 -3.20277761e-01]
#   [ 7.24525655e-02  4.75643752e-02  6.39859494e-02]
#   [-2.91862446e-02 -1.42339853e-02 -2.68650226e-02]
#   [-5.94546897e-02 -2.49609008e-02 -5.37257455e-02]]
#
#  [[ 2.53283447e-02 -4.99396420e-03  2.25920364e-02]
#   [ 2.38409890e-02  8.70411664e-02  3.45709718e-02]
#   [-1.35397766e-01 -1.25274830e-02 -1.31989827e-01]
#   [ 4.96843712e-02  5.83546291e-01  7.41098316e-03]]
#
#  [[-1.63928675e-01 -1.07286428e-02 -1.58363906e-01]
#   [ 4.64062303e-02  2.70691342e-03  5.63684836e-02]
#   [ 6.44165618e-02  1.11189670e-01  3.94062082e-02]
#   [-8.51679188e-02 -2.55787770e-02 -7.61845704e-02]]
#
#  [[-2.68008976e-01  1.21132437e-02 -2.73050695e-01]
#   [-6.93590736e-03  1.58466653e-02 -5.23167998e-04]
#   [-2.47853884e-02 -6.79481454e-01 -3.30951039e-02]
#   [-2.30675344e-03  3.29575627e-02 -2.32728624e-03]]
#
#  [[ 5.12950723e-02 -1.86648796e-01  7.36920170e-02]
#   [-2.19437065e-02 -8.81813877e-03 -2.48893274e-02]
#   [-4.66190575e-03 -1.64864958e-02 -1.54079701e-02]
#   [ 5.33331236e-04 -4.38296165e-03  2.32181036e-03]]]

# %% [markdown]
# ## Final Result

# %%
acc_test = test_accuracy(weights, bias)
print('Accuracy on test data: {:0.4f}'.format(acc_test))
# Out:
# Accuracy on test data: 0.6417

# %% [markdown]
# ## Analyze Results
